# %% [markdown]
# <a href="https://colab.research.google.com/github/SophiaRamirez-ITD/Estadisticas/blob/main/UNIDAD4/Practica1Unidad4_Presentacion_y_plataforma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ##** Probabilidad y estadistica**
#
# Unidad 4
#
# **Distribución normal**
#
# Facilitador: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumna: Sophía del Carmen Ramírez López

# %% [markdown]
# **EJERCICIOS DE LA PRESENSTACIÓN "DISTRIBUCIÓN NORMAL"**

# %% [markdown]
# ##Ejercicio 1
# Una revision de los pesos de 500 estudiantes del ITD, evidenció que la media es de 70 kilogramos y la desviación estandar es de 4 kilogramos. Suponiendo que los valores se distribuyen normalmente.
# 1) Generar aleatoriamente las edades de los 500 estudiantes con una media de 70 kg, y una desviación estandar de 4 kg.
# 2) Realizar un histogrma de las edades
# 3) Graficar la función de densidad de probabilidad.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
# Generar datos para la distribucion normal
media = 70 # Media
desv_std = 4 #Desviación estándar
num_datos = 500
#generamos los datos de manera aleatoria y lon ponemos en una lista (array)
datos = np.random.normal(media, desv_std, num_datos)
datos [0:50] # Mostrar los primeros 50
# Out:
# array([71.67236554, 66.60475223, 68.36117327, 68.53747503, 72.25950412,
#        70.36255411, 70.31694155, 72.99818894, 64.20656244, 75.61808336,
#        66.88028283, 70.29973168, 64.91594204, 74.78668245, 69.91221666,
#        73.1085232 , 65.89633441, 69.80247575, 75.02862848, 65.96514217,
#        73.04977783, 69.45467734, 75.29150012, 71.23348024, 73.4352126 ,
#        61.58196094, 70.35296297, 71.73014088, 72.46159015, 70.86474486,
#        67.67500685, 68.79194383, 73.71042135, 70.05684107, 76.55254737,
#        65.36607429, 70.07188572, 75.43700916, 77.79306165, 70.98631049,
#        65.89897421, 72.40440928, 59.26327254, 68.67476437, 68.92708934,
#        71.8536719 , 65.25414204, 67.8834572 , 72.92111522, 80.31624209])

# %%
#Crear un rango de valores para crera una densidad
x = np.linspace(media - 3*desv_std, media + 3*desv_std, num_datos)

#Calcular la pdf de la distribucion normal

pdf = 1/ (desv_std * np.sqrt(2* np.pi))* np.exp(-(x- media)**2/(2* desv_std**2))

# %%
#Imprimir solo 50 valores
print ("Imprimir los primeros 50 valores de x ", x [0:50], " , y los primeros 50 pdf ", pdf [0:50])
pdf[0:50]
# Out:
# Imprimir los primeros 50 valores de x  [58.         58.04809619 58.09619238 58.14428858 58.19238477 58.24048096
#  58.28857715 58.33667335 58.38476954 58.43286573 58.48096192 58.52905812
#  58.57715431 58.6252505  58.67334669 58.72144289 58.76953908 58.81763527
#  58.86573146 58.91382766 58.96192385 59.01002004 59.05811623 59.10621242
#  59.15430862 59.20240481 59.250501   59.29859719 59.34669339 59.39478958
#  59.44288577 59.49098196 59.53907816 59.58717435 59.63527054 59.68336673
#  59.73146293 59.77955912 59.82765531 59.8757515  59.9238477  59.97194389
#  60.02004008 60.06813627 60.11623246 60.16432866 60.21242485 60.26052104
#  60.30861723 60.35671343]  , y los primeros 50 pdf  [0.00110796 0.00114858 0.0011905  0.00123379 0.00127846 0.00132455
#  0.00137211 0.00142118 0.00147178 0.00152397 0.00157777 0.00163325
#  0.00169042 0.00174935 0.00181007 0.00187262 0.00193706 0.00200342
#  0.00207176 0.00214212 0.00221455 0.0022891  0.00236581 0.00244475
# ...

# %%
# Graficar histograma
plt.figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, color='b')
plt.title('Distribucion normal')
plt.xlabel('Peso en kg de los estudiantes')
plt.grid(True)
plt.show()

# %%
pdf.size, num_datos
# Out:
# (500, 500)

# %%
#Visualizar la PDF
plt.figure(figsize=(6,4))
plt.plot(x, pdf, label= 'Normal:(media:{}; ds:{})'.format(np.round(media, 2), np.round(desv_std, 2)))
plt.title(' Funcion de densidad de probabilidad (PDF) - Distribución Normal')
plt.xlabel('Peso en kg de los estudiantes')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# poner todo junto

# %%
#graficar hisstograma
plt.figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, density=True, color='b')
plt.plot(x, pdf, 'k', linewidth =2)

plt.title('Distribucion Normal')
plt.xlabel('Peso en kg de los estudiantes')
plt.grid(True)
plt.show()

# %% [markdown]
# ##EJERCICIO 2
# Una revision de los pesos de 500 estudiantes del ITD, evidenció que la media es de 70 kilogramos y la desviacion estandar es de 4 kilogramos. Suponiendo que los valores se distribuyen normalmente. Hallar lo siguiente:
#
# Cuantos estudiantes pesan menos de 75 kg.
#
# Cuantos estudiantes pesan menos de 62 kg.
#
# Cuantos estudiantes pesan mas de 79 kg.
#
# Primero necesitamos calcular la probabilidad de que un estudiante pese menos de 75 kg utilizando la función de distribución acumulativa (CDF) de la distribución normal

# %%
plt.figure(figsize=(6,4))

#parametros de la distribucion normal
media = 70 #media
desv_std = 4 #desviacion estandar
total_estudiantes = 500

#VARIABLE para Calculo de la probabilidad de queun estudiante pese menos de 75 kg
peso_limite = 79

#primero necesitamos calcular la probabilidad de que un estudiante pese menos
#de 75 kg utilizando la funcion de distribucion acumulativa (CDF) de la distribucion normal
prob_menos_75kg = norm.cdf(peso_limite, media, desv_std)

# %%
#Calculo del numero de estudiantes que oesan menos de 75 kg
estudiantes_menos_75kg = total_estudiantes * prob_menos_75kg

print("La probabilidad de que un estudiante pese menos de 75kg es de: ", prob_menos_75kg)
print("El numero de estudiantes que pesan menos de 75kg es de: ", estudiantes_menos_75kg)


 #Graficar la distribucion normal
x = np.linspace(media - 4 * desv_std, media + 4*desv_std, 1000)
y= norm.pdf(x, media, desv_std)

plt.plot(x,y, 'b', linewidth=2)
plt.fill_between(x,y, where=(x <= peso_limite), color='skyblue', alpha=0.5)

plt.title('Probabilidad de que un estudiante pese menos de 62kg, \n $\mu= 70$, $\sigma=4$, X=500')
plt.xlabel('PesO (KG)')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
plt.show()
# Out:
# La probabilidad de que un estudiante pese menos de 75kg es de:  0.9877755273449553
# El numero de estudiantes que pesan menos de 75kg es de:  493.88776367247766

# %% [markdown]
# ##Cuantos estudiantes pesan menos de 62 kg

# %%
plt.figure(figsize=(6,4))

#Parámetros de La distribución normal
media = 70 # Media
desv_std= 4 # Desviación estándar
total_estudiantes= 500
#VARIABLE para Cálculo de La probabilidad de que un estudiante pese menos de 75 kg
peso_limite = 62

#Primero necesitamos calcular La probabilidad de que un estudiante pese menos
# de 75 kg utilizando la función de distribución acumulativa (CDF) de la distribución normal
prob_menos_62kg =norm.cdf(peso_limite, media, desv_std)

#Cálculo del número de estudiantes que pesan menos de 75 kg
estudiantes_menos_62kg= total_estudiantes * prob_menos_62kg
print("Probabilidad de que un estudiante pese menos de 62 kg:", prob_menos_62kg)
print("Número de estudiantes que pesan menos de 75 kg:", estudiantes_menos_62kg)
# Out:
# Probabilidad de que un estudiante pese menos de 62 kg: 0.022750131948179195
# Número de estudiantes que pesan menos de 75 kg: 11.375065974089598

# %%
# Calcular la distribución normal
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)

#Graficar la distribución normal
plt.plot(x, y, 'b', linewidth=2)
plt.fill_between (x, y, where=(x <= peso_limite), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese menos de 62 kg, \n $\mu=70$, $\sigma=4$, X=500')
plt.xlabel('Peso (kg)')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
plt.show()

# %% [markdown]
# CUANTOS ESTUDIANTE PESAN MAS DE 79 KG

# %%
plt.figure(figsize=(6,4))

#parametros de la distribucion normal
media = 70 #media
desv_std = 4 #desviacion estandar
peso_limite = 79
total_estudiantes = 500

#calculamos la probabilida de que un estudiante pese menos o igual a 79kg
prob_menos_79kg = norm.cdf(peso_limite, media, desv_std)

#la probabilidad de que un estudiante pese mas de 79kg
prob_mas_79kg = 1 - prob_menos_79kg

#Calculamos el numero aproximado de estudiantes que pesan mas de 79 kg
estudiantes_mas_79kg = total_estudiantes * prob_mas_79kg

print("La probabilidad de que un estudiante pese mas de 79kg es de: ", prob_mas_79kg)
print("El numero aproximado de estudiantes que pesen mas de 79kg es de: ", estudiantes_mas_79kg)
# Out:
# La probabilidad de que un estudiante pese mas de 79kg es de:  0.012224472655044671
# El numero aproximado de estudiantes que pesen mas de 79kg es de:  6.112236327522336

# %%
#Calcular la funcion de desnsidad de probabilidad de La distribucion normal
x = np.linspace(media - 4*desv_std, media + 4*desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)

plt.plot(x,y, 'b', linewidth=2)
plt.fill_between(x,y, where=(x >= peso_limite), color='skyblue', alpha=0.5)
plt.title('Probabiliadd de que un estudaiante pese mas de 79kg  \n $\mu= 70$, $\sigma=4$, X=500')

plt.xlabel('PesO (KG)')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
plt.show()

# %% [markdown]
# **EJERCICIO DE LA PLATAFORMA "DISTRIBUCIÓN NORMAL"**

# %% [markdown]
# En base a los datos de los ejercicios anteriores, encontrar:
#
# 1) La probabilidad de estudiantes que pesan más de 68 y menos de 72 kg.
#
# 2) Cuantos estudiantes pesan más de 68 y menos de 72 kg.

# %% [markdown]
# PROBABILIDAD Y CANTIDAD DE ALUMNOS QUE PESAN MENOS DE 72 KG

# %%
plt.figure(figsize=(6,4))

#parametros de la distribucion normal
media = 70 #media
desv_std = 4 #desviacion estandar
total_estudiantes = 500

#VARIABLE para Calculo de la probabilidad de queun estudiante pese menos de 72 kg
peso_limite = 76

#primero necesitamos calcular la probabilidad de que un estudiante pese menos
#de 72 kg utilizando la funcion de distribucion acumulativa (CDF) de la distribucion normal
prob_menos_72kg = norm.cdf(peso_limite, media, desv_std)

# %%
#Calculo del numero de estudiantes que oesan menos de 72 kg
estudiantes_menos_72kg = total_estudiantes * prob_menos_72kg

print("La probabilidad de que un estudiante pese menos de 72kg es de: ", prob_menos_72kg)
print("El numero de estudiantes que pesan menos de 72kg es de: ", estudiantes_menos_72kg)


 #Graficar la distribucion normal
x = np.linspace(media - 4 * desv_std, media + 4*desv_std, 1000)
y= norm.pdf(x, media, desv_std)

plt.plot(x,y, 'b', linewidth=2)
plt.fill_between(x,y, where=(x <= peso_limite), color='skyblue', alpha=0.5)

plt.title('Probabilidad de que un estudiante pese menos de 72kg, \n $\mu= 70$, $\sigma=4$, X=500')
plt.xlabel('PesO (KG)')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
plt.show()
# Out:
# La probabilidad de que un estudiante pese menos de 72kg es de:  0.9331927987311419
# El numero de estudiantes que pesan menos de 72kg es de:  466.59639936557096

# %% [markdown]
# PROBABILIDAD Y CANTIDAD DE ALUMNOS QUE PESAN MÁS DE 68 KG

# %%
plt.figure(figsize=(6,4))

#parametros de la distribucion normal
media = 70 #media
desv_std = 4 #desviacion estandar
peso_limite = 72
total_estudiantes = 500

#calculamos la probabilida de que un estudiante pese menos o igual a 68kg
prob_menos_68kg = norm.cdf(peso_limite, media, desv_std)

#la probabilidad de que un estudiante pese mas de 68kg
prob_mas_68kg = 1 - prob_menos_68kg

#Calculamos el numero aproximado de estudiantes que pesan mas de 68 kg
estudiantes_mas_68kg = total_estudiantes * prob_mas_68kg

print("La probabilidad de que un estudiante pese mas de 68kg es de: ", prob_mas_68kg)
print("El numero aproximado de estudiantes que pesen mas de 68kg es de: ", estudiantes_mas_68kg)
# Out:
# La probabilidad de que un estudiante pese mas de 68kg es de:  0.3085375387259869
# El numero aproximado de estudiantes que pesen mas de 68kg es de:  154.26876936299345

# %%
#Calcular la funcion de desnsidad de probabilidad de La distribucion normal
x = np.linspace(media - 4*desv_std, media + 4*desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)

plt.plot(x,y, 'b', linewidth=2)
plt.fill_between(x,y, where=(x >= peso_limite), color='skyblue', alpha=0.5)
plt.title('Probabiliadd de que un estudaiante pese mas de 68kg  \n $\mu= 70$, $\sigma=4$, X=500')

plt.xlabel('PesO (KG)')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
plt.show()
