# %% [markdown]
# <a href="https://colab.research.google.com/github/SophiaRamirez-ITD/Estadisticas/blob/main/UNIDAD1/Pr%C3%A1ctica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Instituto Tecnologico de Mexico Campus Durango**
#
# Ing.Sistemas Computacionales
#
# ##**Unidad 1**
#
# # **Probabilidad y Estadistica**
#
# ### Practica 1: Estadistica Descriptiva Basica e Histogramas
#
# **Alumnos**:
# Sophía del Carmen Ramírez López
#
# Emmanuel Fernando Alcala Acosta
#
#
# **Docente:**
# José Gabriel Rodríguez Rivas
#
#
# ![image.png](data:image/png;base64,...)

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [65.23, 69.0, 68.87, 95.13, 63.27, 54.27, 51.67, 54.36, 94.43, 74.79, 77.26, 58.88, 75.13, 61.05, 55.29, 77.47, 69.64, 60.93, 61.12, 72.03, 99.64, 61.39, 95.04, 50.02, 81.37, 82.71, 82.69, 58.89, 78.19, 70.81, 60.0, 83.69, 86.79, 85.53, 69.28, 72.61, 83.18, 50.91, 60.61, 54.74, 74.69, 68.83, 69.44, 93.87, 57.7, 64.92, 97.98, 71.04, 94.73, 67.94, 82.6, 94.44, 52.78, 71.9, 65.06, 63.22, 83.7, 69.17, 50.76, 50.03, 67.07, 91.12, 81.91, 84.7, 67.8, 53.48, 87.32, 55.71, 68.73, 86.56, 95.93, 59.83, 86.32, 88.66, 80.66, 68.04, 59.03, 89.37, 78.52, 96.74, 59.85, 57.68, 81.56, 76.21, 57.68, 51.7, 67.46, 94.83, 88.87, 80.61, 65.9, 99.3, 57.93, 55.99, 76.15, 53.15, 89.55, 98.02, 65.15, 50.44]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100), 2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [59.05, 74.43, 51.2, 70.96, 97.56, 98.41, 65.94, 96.07, 88.84, 96.7, 64.36, 86.26, 94.96, 97.18, 50.14, 58.85, 96.01, 73.35, 56.8, 91.54, 56.29, 55.28, 99.87, 65.64, 75.06, 55.67, 56.82, 77.94, 85.53, 91.33, 92.68, 79.72, 64.88, 81.97, 87.84, 94.6, 89.55, 68.24, 95.52, 92.49, 68.75, 70.87, 74.15, 58.41, 71.48, 75.82, 66.6, 59.74, 67.39, 95.97, 64.19, 93.76, 66.9, 94.61, 97.73, 51.91, 71.5, 92.75, 59.0, 83.44, 83.95, 77.72, 85.63, 84.79, 57.84, 76.03, 61.48, 51.65, 57.59, 67.52, 84.36, 64.02, 75.52, 64.11, 62.93, 66.77, 84.08, 56.39, 75.71, 87.87, 53.23, 91.46, 67.36, 66.86, 98.45, 82.76, 80.06, 64.4, 53.07, 82.97, 63.99, 64.76, 63.06, 51.43, 61.24, 59.51, 98.22, 86.08, 51.02, 55.63]

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print ("Estadistica descriptiva de la Fabrica 1 \n", "\n Media: ", media1,
       "\n Mediana: ", mediana1, "\n Moda: ", moda1, "\n Maximo: ", maximo1,
       "\n Minimo: ", minimo1, "\n Rango: ", rango1)
# Out:
# Estadistica descriptiva de la Fabrica 1
#
#  Media:  72.4824
#  Mediana:  69.53999999999999
#  Moda:  57.68
#  Maximo:  99.64
#  Minimo:  50.02
#  Rango:  49.62

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print ("Estadistica descriptiva de la Fabrica 2 \n", "\n Media: ", media2,
       "\n Mediana: ", mediana2, "\n Moda: ", moda2, "\n Maximo: ", maximo2,
       "\n Minimo: ", minimo2, "\n Rango: ", rango2)
# Out:
# Estadistica descriptiva de la Fabrica 2
#
#  Media:  74.4202
#  Mediana:  72.425
#  Moda:  59.05
#  Maximo:  99.87
#  Minimo:  50.14
#  Rango:  49.730000000000004

# %% [markdown]
# # Dispersion de los datos

# %%
desviacion_estandar_fabrica1 = stdev(fabrica1)
print(desviacion_estandar_fabrica1)
# Out:
# 14.420101368393617

# %%
desviacion_estandar_fabrica2 = stdev(fabrica2)
print(desviacion_estandar_fabrica2)
# Out:
# 15.033172140505163

# %%
plt.figure(figsize= (8,6) )
plt.hist(fabrica1,bins=10,alpha=0.2, color="b", edgecolor="black")
plt.axvline(media1,color="b",linestyle="dashed",linewidth=2,label=f"Media: {media1:.2f}")
plt.axvline(mediana1,color="r",linestyle="dashed",linewidth=2,label=f"Mediana: {mediana1:.2f}")
plt.axvline(moda1,color="y",linestyle="dashed",linewidth=2,label=f"Moda: {moda1:.2f}")

plt.axvline(media1 - desviacion_estandar_fabrica1,color= "black",linestyle= "dashed",linewidth= 2,label= f"Desv.Estandar: {desviacion_estandar_fabrica1:.2f}")
plt.axvline(media1+desviacion_estandar_fabrica1,color="black",linestyle="dashed",linewidth=2)

plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.title("Produccion diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize= (8,6) )
plt.hist(fabrica2,bins=10,alpha=0.2, color="b", edgecolor="black")
plt.axvline(media2,color="b",linestyle="dashed",linewidth=2,label=f"Media: {media2:.2f}")
plt.axvline(mediana2,color="r",linestyle="dashed",linewidth=2,label=f"Mediana: {mediana2:.2f}")
plt.axvline(moda2,color="y",linestyle="dashed",linewidth=2,label=f"Moda: {moda2:.2f}")

plt.axvline(media2 - desviacion_estandar_fabrica2,color= "black",linestyle= "dashed",linewidth= 2,label= f"Desv.Estandar: {desviacion_estandar_fabrica2:.2f}")
plt.axvline(media2+desviacion_estandar_fabrica2,color="black",linestyle="dashed",linewidth=2)

plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.title("Produccion diaria de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# #Densidad

# %%
import seaborn as sns

# %%
#La densidad grafica es una forma de visualizar la distribucion de datos en un
#intervalo o periodo de tiempo continuo
#Se trata de un histograma que usa el suavisado de kernel para trazar valores,
#lo que permite obtener distribuciones mas suaves al reducir el ruido
#Una curva de densidad muestra la ubicacion de la media y la mediana de una
#distribucion

sns.histplot( x = fabrica1, kde = True, kde_kws = {'bw_adjust': 0.5}, bins = 10)
# Out:
# <Axes: ylabel='Count'>
