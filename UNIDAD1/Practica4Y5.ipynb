# %% [markdown]
# <a href="https://colab.research.google.com/github/SophiaRamirez-ITD/Estadisticas/blob/main/UNIDAD1/Practica4Y5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Instituto Tecnologico de Mexico Campus Durango**
#
# Ing.Sistemas Computacionales
#
# ##**Unidad 1**
#
# # **Probabilidad y Estadistica**
#
# ### Practica 4: Tabla de frecuencias y regla de Sturges
#
# **Alumnos**:
# Sophia del Carmen Ramírez López
#
#
# **Docente:**
# José Gabriel Rodríguez Rivas
#
#
# ![image.png](data:image/png;base64,...)

# %%
import random

# %%
#Basados en el libro estadistica para administracion pagina 12
#creamos una lista vacia que representa la edad de 100 personas

edades = []

#Hacemos un ciclo para generar 100 numeros aleatorios que representan la edad de las personas
for i in range(100):
  numero_aleatorio = random.randint(18, 70)
  edades.append(numero_aleatorio)

print(edades)
# Out:
# [63, 49, 67, 34, 21, 46, 68, 45, 43, 70, 28, 28, 60, 66, 39, 62, 62, 37, 49, 68, 40, 36, 38, 21, 37, 45, 36, 65, 23, 43, 68, 44, 32, 18, 48, 31, 31, 49, 29, 37, 20, 66, 22, 43, 49, 20, 34, 39, 24, 35, 59, 32, 55, 59, 34, 28, 69, 18, 30, 49, 48, 27, 29, 39, 66, 55, 60, 19, 67, 57, 40, 32, 40, 51, 28, 23, 51, 32, 25, 65, 20, 57, 29, 37, 48, 50, 40, 32, 56, 49, 40, 62, 32, 22, 42, 23, 70, 33, 30, 23]

# %%
import pandas as pd

# %%
#Crear un DataFrame de pandas con los numeros aleatorios
df = pd.DataFrame(edades, columns=["Edad"])
df.head()
# Out:
#    Edad
# 0    63
# 1    49
# 2    67
# 3    34
# 4    21

# %%
#Calcular la tabla de distribucion de frecuencias
tabla_frecuencias = df["Edad"].value_counts().reset_index()
tabla_frecuencias.columns = ["Edad", "Frecuencia"]
tabla_frecuencias = tabla_frecuencias.sort_values(by="Edad")

# imprimir la tabla de frecuencias
print("Tabla de Distribucion de Frecuencias")
tabla_frecuencias
# Out:
# Tabla de Distribucion de Frecuencias
#     Edad  Frecuencia
# 21    18           2
# 32    19           1
# 11    20           3
# 27    21           2
# 15    22           2
# 3     23           4
# 39    24           1
# 33    25           1
# 36    27           1
# 5     28           4
# 7     29           3
# 29    30           2
# 19    31           2
# 0     32           6
# 43    33           1
# 14    34           3
# 38    35           1
# 22    36           2
# 4     37           4
# 41    38           1
# 9     39           3
# 2     40           5
# 34    42           1
# 12    43           3
# 40    44           1
# 26    45           2
# 42    46           1
# 6     48           3
# 1     49           6
# 30    50           1
# 16    51           2
# 18    55           2
# 31    56           1
# 20    57           2
# 17    59           2
# 24    60           2
# 8     62           3
# 35    63           1
# 23    65           2
# 10    66           3
# ...

# %%
tabla_frecuencias["Frec Relativa"] = tabla_frecuencias["Frecuencia"] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 21    18           2           0.02
# 32    19           1           0.01
# 11    20           3           0.03
# 27    21           2           0.02
# 15    22           2           0.02
# 3     23           4           0.04
# 39    24           1           0.01
# 33    25           1           0.01
# 36    27           1           0.01
# 5     28           4           0.04
# 7     29           3           0.03
# 29    30           2           0.02
# 19    31           2           0.02
# 0     32           6           0.06
# 43    33           1           0.01
# 14    34           3           0.03
# 38    35           1           0.01
# 22    36           2           0.02
# 4     37           4           0.04
# 41    38           1           0.01
# 9     39           3           0.03
# 2     40           5           0.05
# 34    42           1           0.01
# 12    43           3           0.03
# 40    44           1           0.01
# ...

# %%
tabla_frecuencias["Frec Porcentual"] = tabla_frecuencias["Frecuencia"] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 21    18           2           0.02              2.0
# 32    19           1           0.01              1.0
# 11    20           3           0.03              3.0
# 27    21           2           0.02              2.0
# 15    22           2           0.02              2.0
# 3     23           4           0.04              4.0
# 39    24           1           0.01              1.0
# 33    25           1           0.01              1.0
# 36    27           1           0.01              1.0
# 5     28           4           0.04              4.0
# 7     29           3           0.03              3.0
# 29    30           2           0.02              2.0
# 19    31           2           0.02              2.0
# 0     32           6           0.06              6.0
# 43    33           1           0.01              1.0
# 14    34           3           0.03              3.0
# 38    35           1           0.01              1.0
# ...

# %%
tabla_frecuencias["Frec Acumulada"] = tabla_frecuencias["Frecuencia"].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 21    18           2           0.02              2.0               2
# 32    19           1           0.01              1.0               3
# 11    20           3           0.03              3.0               6
# 27    21           2           0.02              2.0               8
# 15    22           2           0.02              2.0              10
# 3     23           4           0.04              4.0              14
# 39    24           1           0.01              1.0              15
# 33    25           1           0.01              1.0              16
# 36    27           1           0.01              1.0              17
# 5     28           4           0.04              4.0              21
# 7     29           3           0.03              3.0              24
# 29    30           2           0.02              2.0              26
# 19    31           2           0.02              2.0              28
# ...

# %% [markdown]
# ##Regla de sturges
#
# 1.Es una regla que calcula el numero de clases o intervalos idoneo en los que se debe dividir un conjunto de datos
#
# 2.Establece que el numero de clases es igual a uno mas el logaritmo en base del numero total de datos
#
# c = 1 + log2(N)
# donde N es el tamaño de la muestra

# %%
import math

# %%
print(edades)
# Out:
# [63, 49, 67, 34, 21, 46, 68, 45, 43, 70, 28, 28, 60, 66, 39, 62, 62, 37, 49, 68, 40, 36, 38, 21, 37, 45, 36, 65, 23, 43, 68, 44, 32, 18, 48, 31, 31, 49, 29, 37, 20, 66, 22, 43, 49, 20, 34, 39, 24, 35, 59, 32, 55, 59, 34, 28, 69, 18, 30, 49, 48, 27, 29, 39, 66, 55, 60, 19, 67, 57, 40, 32, 40, 51, 28, 23, 51, 32, 25, 65, 20, 57, 29, 37, 48, 50, 40, 32, 56, 49, 40, 62, 32, 22, 42, 23, 70, 33, 30, 23]

# %%
df = pd.DataFrame({"Edad" : edades})
df
# Out:
#     Edad
# 0     63
# 1     49
# 2     67
# 3     34
# 4     21
# ..   ...
# 95    23
# 96    70
# 97    33
# 98    30
# 99    23
#
# [100 rows x 1 columns]

# %%
#Calcular el numero de intervalos usando la regla de struges
n = len(edades)
k = int(1 + math.log2(n))
print("Valor de n: ", n, " \nNumero de intervalos: ", k)
# Out:
# Valor de n:  100
# Numero de intervalos:  7

# %%
tabla_frecuencias = pd.cut( df["Edad"], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns = ["Clase", "Frec"]
tabla_frecuencias
# Out:
#               Clase  Frec
# 0  (32.857, 40.286]    20
# 1  (25.429, 32.857]    18
# 2  (17.947, 25.429]    16
# 3  (47.714, 55.143]    14
# 4    (62.571, 70.0]    14
# 5  (55.143, 62.571]    10
# 6  (40.286, 47.714]     8

# %%
tabla_frecuencias = tabla_frecuencias.sort_values(by="Clase")
tabla_frecuencias
# Out:
#               Clase  Frec
# 2  (17.947, 25.429]    16
# 1  (25.429, 32.857]    18
# 0  (32.857, 40.286]    20
# 6  (40.286, 47.714]     8
# 3  (47.714, 55.143]    14
# 5  (55.143, 62.571]    10
# 4    (62.571, 70.0]    14

# %%
tabla_frecuencias["Frec Rel"] = tabla_frecuencias["Frec"] / n
tabla_frecuencias["Frec Proc"] = tabla_frecuencias['Frec'] / n * 100
tabla_frecuencias['Frec Acum'] = tabla_frecuencias['Frec'].cumsum()
tabla_frecuencias['Frec Rel Acum'] = tabla_frecuencias['Frec Rel'].cumsum()
tabla_frecuencias['Frec proc Acum'] = tabla_frecuencias['Frec Proc'].cumsum()

# %%
import matplotlib.pyplot as plt
plt.hist(edades, bins=k)
plt.title ("Histograma de edades basado en la funion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funion de matplotlib con valores estandar')

# %%
plt.hist(df['Edad'], bins= k, alpha=0.5)
plt.title("Histograma de edades basado en la regla de Sturgles")
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# # Practica 5 diagrama de cajas y bigotes
# ## Alumnos:
# ##Gloria Angelica Monreal Muñoz,Sophia del Carmen Ramírez López y Emmanuel  Alcala Acosta
#
# #### 1.Las lineas se usan para indicar la variabilidad fuera de los cuartiles superior e inferior
# #### 2.Los valores atipicos se representan a veces como puntos individuales que estan en linea con los bigotes
# #### 3.Si los datos son simetricos, lamediana estara en el centro de la caja
# #### 4.Si los datos esatn sesgados, la mediana estara mas cerca de la parte superior e inferior de la caja.
# #### 5.Los extremos de arriba y abajo de la caja indicas los cuantiles, o percentiles , 25 y 75 estos dos cuantiles tambien se conocen como cuartiles, porque separan cuartos (25%) de los datos. L alongitud de la caja es la diferencia en estos dos percentiles y se conocen como rango intercuartilico (IQR).
# #### 6.Los diagramas caja-bigote son muy utiles para comparar dos o mas conjutos de datos.

# %%
edades2 = []

#Hacemos un ciclo para generar 100 numeros aleatorios que representan la edad de las personas
for i in range(100):
  numero_aleatorio = random.randint(29, 87)
  edades2.append(numero_aleatorio)

print(edades2)
# Out:
# [79, 29, 83, 79, 30, 61, 56, 48, 87, 83, 34, 39, 33, 52, 30, 58, 55, 74, 83, 83, 83, 51, 35, 85, 45, 37, 49, 49, 80, 82, 67, 60, 55, 44, 35, 75, 85, 67, 51, 35, 39, 34, 61, 49, 80, 58, 31, 52, 81, 59, 83, 68, 85, 55, 70, 66, 51, 86, 31, 68, 51, 75, 34, 58, 66, 70, 84, 63, 50, 49, 35, 45, 32, 56, 69, 65, 79, 81, 55, 49, 82, 54, 65, 58, 63, 43, 78, 52, 61, 41, 79, 63, 68, 52, 52, 49, 77, 71, 39, 71]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades,
                     vert = True,
                     patch_artist = True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2,
                     vert = True,
                     patch_artist = True)
ax2.set_title('Edades Encuesta 2')
plt.show()

# %%
edades2.append(130)
#append sirve para agregar valores a la lista

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades,
                     vert = True,
                     patch_artist = True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2,
                     vert = True,
                     patch_artist = True)
ax2.set_title('Edades Encuesta 2')
plt.show()
