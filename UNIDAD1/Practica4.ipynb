# %% [markdown]
# <a href="https://colab.research.google.com/github/SophiaRamirez-ITD/Estadisticas/blob/main/UNIDAD1/Practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Instituto Tecnologico de Mexico Campus Durango**
#
# Ing.Sistemas Computacionales
#
# ##**Unidad 1**
#
# # **Probabilidad y Estadistica**
#
# ### Practica 4: Tabla de frecuencias y regla de Sturges
#
# **Alumnos**:
# Sophia del Carmen Ramírez López
#
#
# **Docente:**
# José Gabriel Rodríguez Rivas
#
#
# ![image.png](data:image/png;base64,...)

# %%
import random

# %%
#Basados en el libro estadistica para administracion pagina 12
#creamos una lista vacia que representa la edad de 100 personas

edades = []

#Hacemos un ciclo para generar 100 numeros aleatorios que representan la edad de las personas
for i in range(100):
  numero_aleatorio = random.randint(18, 70)
  edades.append(numero_aleatorio)

print(edades)
# Out:
# [54, 48, 44, 45, 60, 65, 25, 36, 60, 41, 58, 25, 56, 45, 23, 34, 58, 59, 20, 21, 67, 44, 27, 42, 70, 64, 47, 52, 33, 65, 60, 50, 24, 29, 21, 26, 29, 70, 33, 36, 31, 64, 50, 66, 53, 68, 24, 68, 59, 50, 68, 28, 54, 27, 43, 58, 25, 33, 59, 61, 66, 35, 65, 41, 44, 28, 36, 34, 56, 21, 32, 25, 28, 41, 44, 27, 19, 41, 64, 59, 37, 41, 62, 58, 69, 54, 61, 63, 32, 70, 32, 47, 29, 46, 19, 42, 30, 34, 43, 56]

# %%
import pandas as pd

# %%
#Crear un DataFrame de pandas con los numeros aleatorios
df = pd.DataFrame(edades, columns=["Edad"])
df.head()
# Out:
#    Edad
# 0    54
# 1    48
# 2    44
# 3    45
# 4    60

# %%
#Calcular la tabla de distribucion de frecuencias
tabla_frecuencias = df["Edad"].value_counts().reset_index()
tabla_frecuencias.columns = ["Edad", "Frecuencia"]
tabla_frecuencias = tabla_frecuencias.sort_values(by="Edad")

# imprimir la tabla de frecuencias
print("Tabla de Distribucion de Frecuencias")
tabla_frecuencias
# Out:
# Tabla de Distribucion de Frecuencias
#     Edad  Frecuencia
# 25    19           2
# 41    20           1
# 6     21           3
# 42    23           1
# 21    24           2
# 2     25           4
# 38    26           1
# 15    27           3
# 7     28           3
# 10    29           3
# 43    30           1
# 37    31           1
# 9     32           3
# 12    33           3
# 17    34           3
# 30    35           1
# 16    36           3
# 29    37           1
# 0     41           5
# 28    42           2
# 22    43           2
# 1     44           4
# 23    45           2
# 31    46           1
# 27    47           2
# 39    48           1
# 11    50           3
# 35    52           1
# 36    53           1
# 5     54           3
# 20    56           3
# 3     58           4
# 4     59           4
# 18    60           3
# 26    61           2
# 32    62           1
# 33    63           1
# 13    64           3
# 19    65           3
# 24    66           2
# 40    67           1
# 8     68           3
# 34    69           1
# 14    70           3

# %%
tabla_frecuencias["Frec Relativa"] = tabla_frecuencias["Frecuencia"] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 25    19           2           0.02
# 41    20           1           0.01
# 6     21           3           0.03
# 42    23           1           0.01
# 21    24           2           0.02
# 2     25           4           0.04
# 38    26           1           0.01
# 15    27           3           0.03
# 7     28           3           0.03
# 10    29           3           0.03
# 43    30           1           0.01
# 37    31           1           0.01
# 9     32           3           0.03
# 12    33           3           0.03
# 17    34           3           0.03
# 30    35           1           0.01
# 16    36           3           0.03
# 29    37           1           0.01
# 0     41           5           0.05
# 28    42           2           0.02
# 22    43           2           0.02
# 1     44           4           0.04
# 23    45           2           0.02
# 31    46           1           0.01
# 27    47           2           0.02
# 39    48           1           0.01
# 11    50           3           0.03
# 35    52           1           0.01
# 36    53           1           0.01
# 5     54           3           0.03
# 20    56           3           0.03
# 3     58           4           0.04
# 4     59           4           0.04
# 18    60           3           0.03
# 26    61           2           0.02
# 32    62           1           0.01
# 33    63           1           0.01
# 13    64           3           0.03
# 19    65           3           0.03
# 24    66           2           0.02
# 40    67           1           0.01
# 8     68           3           0.03
# 34    69           1           0.01
# 14    70           3           0.03

# %%
tabla_frecuencias["Frec Porcentual"] = tabla_frecuencias["Frecuencia"] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 25    19           2           0.02              2.0
# 41    20           1           0.01              1.0
# 6     21           3           0.03              3.0
# 42    23           1           0.01              1.0
# 21    24           2           0.02              2.0
# 2     25           4           0.04              4.0
# 38    26           1           0.01              1.0
# 15    27           3           0.03              3.0
# 7     28           3           0.03              3.0
# 10    29           3           0.03              3.0
# 43    30           1           0.01              1.0
# 37    31           1           0.01              1.0
# 9     32           3           0.03              3.0
# 12    33           3           0.03              3.0
# 17    34           3           0.03              3.0
# 30    35           1           0.01              1.0
# 16    36           3           0.03              3.0
# 29    37           1           0.01              1.0
# 0     41           5           0.05              5.0
# 28    42           2           0.02              2.0
# 22    43           2           0.02              2.0
# 1     44           4           0.04              4.0
# 23    45           2           0.02              2.0
# 31    46           1           0.01              1.0
# 27    47           2           0.02              2.0
# 39    48           1           0.01              1.0
# 11    50           3           0.03              3.0
# 35    52           1           0.01              1.0
# 36    53           1           0.01              1.0
# 5     54           3           0.03              3.0
# 20    56           3           0.03              3.0
# 3     58           4           0.04              4.0
# 4     59           4           0.04              4.0
# 18    60           3           0.03              3.0
# 26    61           2           0.02              2.0
# 32    62           1           0.01              1.0
# 33    63           1           0.01              1.0
# 13    64           3           0.03              3.0
# 19    65           3           0.03              3.0
# 24    66           2           0.02              2.0
# 40    67           1           0.01              1.0
# 8     68           3           0.03              3.0
# 34    69           1           0.01              1.0
# 14    70           3           0.03              3.0

# %%
tabla_frecuencias["Frec Acumulada"] = tabla_frecuencias["Frecuencia"].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 25    19           2           0.02              2.0               2
# 41    20           1           0.01              1.0               3
# 6     21           3           0.03              3.0               6
# 42    23           1           0.01              1.0               7
# 21    24           2           0.02              2.0               9
# 2     25           4           0.04              4.0              13
# 38    26           1           0.01              1.0              14
# 15    27           3           0.03              3.0              17
# 7     28           3           0.03              3.0              20
# 10    29           3           0.03              3.0              23
# 43    30           1           0.01              1.0              24
# 37    31           1           0.01              1.0              25
# 9     32           3           0.03              3.0              28
# 12    33           3           0.03              3.0              31
# 17    34           3           0.03              3.0              34
# 30    35           1           0.01              1.0              35
# 16    36           3           0.03              3.0              38
# 29    37           1           0.01              1.0              39
# 0     41           5           0.05              5.0              44
# 28    42           2           0.02              2.0              46
# 22    43           2           0.02              2.0              48
# 1     44           4           0.04              4.0              52
# 23    45           2           0.02              2.0              54
# 31    46           1           0.01              1.0              55
# 27    47           2           0.02              2.0              57
# 39    48           1           0.01              1.0              58
# 11    50           3           0.03              3.0              61
# 35    52           1           0.01              1.0              62
# 36    53           1           0.01              1.0              63
# 5     54           3           0.03              3.0              66
# 20    56           3           0.03              3.0              69
# 3     58           4           0.04              4.0              73
# 4     59           4           0.04              4.0              77
# 18    60           3           0.03              3.0              80
# 26    61           2           0.02              2.0              82
# 32    62           1           0.01              1.0              83
# 33    63           1           0.01              1.0              84
# 13    64           3           0.03              3.0              87
# 19    65           3           0.03              3.0              90
# 24    66           2           0.02              2.0              92
# 40    67           1           0.01              1.0              93
# 8     68           3           0.03              3.0              96
# 34    69           1           0.01              1.0              97
# 14    70           3           0.03              3.0             100

# %% [markdown]
# ##Regla de sturges
#
# 1.Es una regla que calcula el numero de clases o intervalos idoneo en los que se debe dividir un conjunto de datos
#
# 2.Establece que el numero de clases es igual a uno mas el logaritmo en base del numero total de datos
#
# c = 1 + log2(N)
# donde N es el tamaño de la muestra

# %%
import math

# %%
print(edades)
# Out:
# [54, 48, 44, 45, 60, 65, 25, 36, 60, 41, 58, 25, 56, 45, 23, 34, 58, 59, 20, 21, 67, 44, 27, 42, 70, 64, 47, 52, 33, 65, 60, 50, 24, 29, 21, 26, 29, 70, 33, 36, 31, 64, 50, 66, 53, 68, 24, 68, 59, 50, 68, 28, 54, 27, 43, 58, 25, 33, 59, 61, 66, 35, 65, 41, 44, 28, 36, 34, 56, 21, 32, 25, 28, 41, 44, 27, 19, 41, 64, 59, 37, 41, 62, 58, 69, 54, 61, 63, 32, 70, 32, 47, 29, 46, 19, 42, 30, 34, 43, 56]

# %%
df = pd.DataFrame({"Edad" : edades})
df
# Out:
#     Edad
# 0     54
# 1     48
# 2     44
# 3     45
# 4     60
# ..   ...
# 95    42
# 96    30
# 97    34
# 98    43
# 99    56
#
# [100 rows x 1 columns]

# %%
#Calcular el numero de intervalos usando la regla de struges
n = len(edades)
k = int(1 + math.log2(n))
print("Valor de n: ", n, " \nNumero de intervalos: ", k)
# Out:
# Valor de n:  100
# Numero de intervalos:  7

# %%
tabla_frecuencias = pd.cut( df["Edad"], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns = ["Clase", "Frec"]
tabla_frecuencias
# Out:
#               Clase  Frec
# 0  (40.857, 48.143]    19
# 1  (26.286, 33.571]    17
# 2  (55.429, 62.714]    17
# 3    (62.714, 70.0]    17
# 4  (18.948, 26.286]    14
# 5  (33.571, 40.857]     8
# 6  (48.143, 55.429]     8

# %%
tabla_frecuencias = tabla_frecuencias.sort_values(by="Clase")
tabla_frecuencias
# Out:
#               Clase  Frec
# 4  (18.948, 26.286]    14
# 1  (26.286, 33.571]    17
# 5  (33.571, 40.857]     8
# 0  (40.857, 48.143]    19
# 6  (48.143, 55.429]     8
# 2  (55.429, 62.714]    17
# 3    (62.714, 70.0]    17

# %%
tabla_frecuencias["Frec Rel"] = tabla_frecuencias["Frec"] / n
tabla_frecuencias["Frec Proc"] = tabla_frecuencias['Frec'] / n * 100
tabla_frecuencias['Frec Acum'] = tabla_frecuencias['Frec'].cumsum()
tabla_frecuencias['Frec Rel Acum'] = tabla_frecuencias['Frec Rel'].cumsum()
tabla_frecuencias['Frec proc Acum'] = tabla_frecuencias['Frec Proc'].cumsum()

# %%
import matplotlib.pyplot as plt
plt.hist(edades, bins=k)
plt.title ("Histograma de edades basado en la funion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funion de matplotlib con valores estandar')

# %%
plt.hist(df['Edad'], bins= k, alpha=0.5)
plt.title("Histograma de edades basado en la regla de Sturgles")
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# # Practica 5 diagrama de cajas y bigotes
# ## Alumnos:
# ##Gloria Angelica Monreal Muñoz,Sophia Ramirez y Emmanuel Alcala
#
# #### 1.Las lineas se usan para indicar la variabilidad fuera de los cuartiles superior e inferior
# #### 2.Los valores atipicos se representan a veces como puntos individuales que estan en linea con los bigotes
# #### 3.Si los datos son simetricos, lamediana estara en el centro de la caja
# #### 4.Si los datos esatn sesgados, la mediana estara mas cerca de la parte superior e inferior de la caja.
# #### 5.Los extremos de arriba y abajo de la caja indicas los cuantiles, o percentiles , 25 y 75 estos dos cuantiles tambien se conocen como cuartiles, porque separan cuartos (25%) de los datos. L alongitud de la caja es la diferencia en estos dos percentiles y se conocen como rango intercuartilico (IQR).
# #### 6.Los diagramas caja-bigote son muy utiles para comparar dos o mas conjutos de datos.

# %%
edades2 = []

#Hacemos un ciclo para generar 100 numeros aleatorios que representan la edad de las personas
for i in range(100):
  numero_aleatorio = random.randint(29, 87)
  edades2.append(numero_aleatorio)

print(edades2)
# Out:
# [72, 58, 83, 45, 67, 61, 69, 40, 82, 76, 35, 59, 36, 86, 34, 81, 81, 49, 34, 69, 71, 59, 84, 36, 61, 49, 71, 65, 46, 58, 67, 31, 87, 71, 67, 72, 38, 35, 74, 80, 29, 45, 42, 62, 47, 87, 39, 34, 57, 87, 73, 48, 70, 69, 54, 81, 34, 75, 60, 57, 29, 84, 34, 58, 39, 35, 82, 73, 53, 83, 68, 36, 42, 31, 38, 62, 50, 81, 83, 68, 75, 85, 29, 29, 74, 78, 56, 83, 87, 62, 54, 33, 41, 48, 77, 41, 60, 52, 32, 29]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades,
                     vert = True,
                     patch_artist = True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2,
                     vert = True,
                     patch_artist = True)
ax2.set_title('Edades Encuesta 2')
plt.show()

# %%
edades2.append(130)
#append sirve para agregar valores a la lista

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades,
                     vert = True,
                     patch_artist = True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2,
                     vert = True,
                     patch_artist = True)
ax2.set_title('Edades Encuesta 2')
plt.show()
